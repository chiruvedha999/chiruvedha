# %%
import pandas as pd

# %%
dt=pd.read_csv(r"C:\Users\Dell\Downloads\cleaned_all_phones.csv")

# %%
data=dt.copy()

# %%
data
# Out:
#             phone_name   brand           os  inches resolution  battery  \
# 0         Y6II Compact  Huawei  Android 5.1    5.00   720x1280     2200
# 1             K20 plus      LG  Android 7.0    5.30   720x1280     2700
# 2       P8 Lite (2017)  Huawei  Android 7.0    5.20  1080x1920     3000
# 3         Redmi Note 4  Xiaomi  Android 6.0    5.50  1080x1920     4100
# 4                  P10  Huawei  Android 7.0    5.10  1080x1920     3200
# ...                ...     ...          ...     ...        ...      ...
# 1507         vivo Y77t    Vivo   Android 13    6.64  1080x2388     5000
# 1508               11x  Realme   Android 13    6.72  1080x2400     5000
# 1509               GT5  Realme   Android 13    6.74  1240x2772     5240
# 1510          GT5 240W  Realme   Android 13    6.74  1240x2772     4600
# 1511  vivo iQOO Z7 Pro    Vivo   Android 13    6.78  1080x2400     4600
#
#      battery_type  ram(GB) announcement_date  weight(g)  ...  video_1080p  \
# ...

# %%
#How many unique  mobile brands are there in the data provided
#What is the average ram size of all the collected data
#Which phone is having the maximum and minimum battery capacity
#What is the maximum battery capacity provided by Huawei Company
#Which Phone brand is providing the highest and lowest ram
#How many phones has android 7.0 as there operating system
#Which Phone is the oldest 
#Which brand produced maximum number of phone in the given data
#Give the count of phones supporting
#4k video
#8k video
#2k video
#10. How many phones supports Li-Po and Li-ion Battery
#11. How many sony phones supports 720x1280 resolution
#12. Print a pivot table for finding the average weights ,total weights,based on brand and battery type

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1512 entries, 0 to 1511
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   phone_name         1512 non-null   object
#  1   brand              1512 non-null   object
#  2   os                 1512 non-null   object
#  3   inches             1512 non-null   float64
#  4   resolution         1512 non-null   object
#  5   battery            1512 non-null   int64
#  6   battery_type       1512 non-null   object
#  7   ram(GB)            1512 non-null   int64
#  8   announcement_date  1512 non-null   object
#  9   weight(g)          1512 non-null   float64
#  10  storage(GB)        1512 non-null   int64
#  11  video_720p         1512 non-null   bool
#  12  video_1080p        1512 non-null   bool
#  13  video_4K           1512 non-null   bool
#  14  video_8K           1512 non-null   bool
#  15  video_30fps        1512 non-null   bool
# ...

# %%
data.head(50)
# Out:
#             phone_name    brand             os  inches resolution  battery  \
# 0         Y6II Compact   Huawei    Android 5.1    5.00   720x1280     2200
# 1             K20 plus       LG    Android 7.0    5.30   720x1280     2700
# 2       P8 Lite (2017)   Huawei    Android 7.0    5.20  1080x1920     3000
# 3         Redmi Note 4   Xiaomi    Android 6.0    5.50  1080x1920     4100
# 4                  P10   Huawei    Android 7.0    5.10  1080x1920     3200
# 5           Xperia XA1     Sony    Android 7.0    5.00   720x1280     2300
# 6             P10 Lite   Huawei    Android 7.0    5.20  1080x1920     3000
# 7             P10 Plus   Huawei    Android 7.0    5.50  1440x2560     3750
# 8     Xperia XA1 Ultra     Sony    Android 7.0    6.00  1080x1920     2700
# 9             X power2       LG    Android 7.0    5.50   720x1280     4500
# 10       Redmi Note 4X   Xiaomi    Android 6.0    5.50  1080x1920     4100
# ...

# %% [markdown]
# # How many unique  mobile brands are there in the data provided

# %%
len(data['brand'].unique())
# Out:
# 13

# %%
#there are 13 unique brands are available in a given set

# %%
data2=data.groupby(['brand'])

# %%
data2.agg({'ram(GB)':['min','max'],'battery':['min','max'],'price(USD)':['max','min'],'announcement_date':['max','min'],'phone_name':'count'})
# Out:
#         ram(GB)     battery       price(USD)         announcement_date  \
#             min max     min   max        max     min               max
# brand
# Apple         2   6    1821  4352    1580.09  189.50        2022-09-07
# Google        4  12    2700  5003    1750.00  238.00        2023-05-10
# Honor         2  16    3000  7250    1500.00   90.00        2023-07-28
# Huawei        1  12    2200  7000    2300.00   90.00        2023-05-23
# LG            1   8    2410  5000    1100.00   70.00        2021-02-22
# Lenovo        2  18    3000  7000     880.00   90.00        2023-07-22
# OnePlus       4  24    3300  5000    1030.00  119.00        2023-08-16
# Oppo          2  16    2900  5000    1350.00  100.00        2023-07-26
# Realme        2  24    3410  6000     839.95   40.00        2023-08-28
# Samsung       1  16    1950  7000    1750.00   60.00        2023-08-07
# Sony          2  12    2300  5000    2000.00  110.00        2023-05-11
# ...

# %% [markdown]
# # What is the average ram size of all the collected data

# %%
data['ram(GB)'].mean()
# Out:
# 6.6838624338624335

# %%
#The average Ram size of all collected data is 6.68

# %% [markdown]
# # Give the count of phones supporting
# #4k video
# #8k video
# #2k video

# %%
data[['video_8K']].value_counts()
# Out:
# video_8K
# False       1426
# True          86
# dtype: int64

# %%
data['video_4K'].value_counts()
# Out:
# True     801
# False    711
# Name: video_4K, dtype: int64

# %%
data['video_1080p'].value_counts()
# Out:
# True     1503
# False       9
# Name: video_1080p, dtype: int64

# %%
#Ther are 801 phones supporting for 4k video ,86 are supporting for 8k video and 1503 are supporting for 2k video

# %% [markdown]
# # Print a pivot table for finding the average weights ,total weights,based on brand and battery type

# %%
data.pivot_table(index='brand',columns='battery',values='weight(g)',aggfunc=['max','mean'],dropna=True)
# Out:
#            max                                                                 \
# battery   1821   1950   2000   2018   2050   2200   2227   2280   2300   2410
# brand
# Apple    148.0    NaN    NaN  144.0    NaN    NaN  135.0    NaN    NaN    NaN
# Google     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Honor      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Huawei     NaN    NaN    NaN    NaN    NaN  175.0    NaN  175.0    NaN    NaN
# LG         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN  139.0
# Lenovo     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# OnePlus    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Oppo       NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Realme     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Samsung    NaN  165.0  130.0    NaN  143.0    NaN    NaN    NaN    NaN    NaN
# ...

# %%
dt=data.loc[data['os']=='Android 7.0']

# %%
dt['phone_name'].count()
# Out:
# 33

# %% [markdown]
# # What is the maximum battery capacity provided by Huawei Company

# %%
data2['battery'].max().loc['Huawei']
# Out:
# 7000

# %%
#The maximum cpacity of provided by huawei company is 7000

# %% [markdown]
# # Which phone is having the maximum and minimum battery capacity

# %%
filt=(data['battery']==data['battery'].max())

# %%
data.loc[filt]['phone_name']
# Out:
# 573    V6
# Name: phone_name, dtype: object

# %%
filt=(data['battery']==data['battery'].min())

# %%
data.loc[filt]['phone_name']
# Out:
# 62             iPhone 8
# 536    iPhone SE (2020)
# Name: phone_name, dtype: object

# %%
#V6 phone is having maximum battery capacity and  iPhone 8,iPhone SE (2020) are having minimum battery capacity

# %% [markdown]
# # Which Phone brand is providing the highest and lowest ram

# %%
filt=(data['ram(GB)']==data['ram(GB)'].max())

# %%
data.loc[filt]['brand']
# Out:
# 1505     Xiaomi
# 1506    OnePlus
# 1510     Realme
# Name: brand, dtype: object

# %%
#Xiaomi,OnePlus and Realme have highest ram(GB)

# %%
filt=(data['ram(GB)']==data['ram(GB)'].min())

# %%
data.loc[filt]['brand']
# Out:
# 27      Huawei
# 28     Samsung
# 69     Samsung
# 133     Huawei
# 182    Samsung
# 230    Samsung
# 236     Huawei
# 244     Xiaomi
# 304    Samsung
# 363         LG
# 550    Samsung
# Name: brand, dtype: object

# %%
#There are 7 brands which are having lowest ram(GB)

# %% [markdown]
# # How many phones has android 7.0 as there operating system

# %%
dt=data.loc[data['os']=='Android 7.0']

# %%
dt['phone_name'].count()
# Out:
# 33

# %%
#There are 33 phones which has Android 7.0 as operating system

# %% [markdown]
# # Which Phone is the oldest

# %%
dt=data.loc[data['announcement_date']==dt['announcement_date'].min()]

# %%
dt['phone_name']
# Out:
# 1    K20 plus
# Name: phone_name, dtype: object

# %%
#K20 plus is the oldest phone

# %% [markdown]
# # Which brand produced maximum number of phone in the given data

# %%
data2['phone_name'].count()
# Out:
# brand
# Apple       22
# Google      19
# Honor      124
# Huawei     137
# LG          75
# Lenovo      43
# OnePlus     47
# Oppo       213
# Realme     157
# Samsung    206
# Sony        37
# Vivo       168
# Xiaomi     264
# Name: phone_name, dtype: int64

# %%
#Xiaomi is producing maximum number of phone in the given data

# %% [markdown]
# # 10. How many phones supports Li-Po and Li-ion Battery

# %%
filt=(data['battery_type']=='Li-Po')

# %%
data.loc[filt]['phone_name'].count()
# Out:
# 1242

# %%
#There are 1242 phones support Li-Po Battery

# %%
filt=(data['battery_type']=='Li-Ion')

# %%
data.loc[filt]['phone_name'].count()
# Out:
# 270

# %%
#There are 270 phones support Li-Po Battery

# %% [markdown]
# # 11. How many sony phones supports 720x1280 resolution

# %%
filt=(data['brand']=='Sony')&(data['resolution']=='720x1280')

# %%
data.loc[filt]['phone_name'].count()
# Out:
# 5

# %%
#There are 5 phones supports 720x1280 resolution
